# %%
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My\ Drive/MachineLearning/lab3

# %% [markdown]
# ##  Lab 3(a) - Implementation of Multi layer perceptron from scratch
# ##  Weightage - 2.4%
#
# Maximum Points in the Lab: 90
#
# ---
# Important points to remember :
#
#
# 1.  Observations for the experiments should be explained.
# 2. All the code should be submitted in the form of a single Jupyter notebook itself.
# 3. Points for each sub-section are mentioned in the appropriate question.
# 4. Make sure to begin early as a few experiments may consume more time to run.
# 5. You can use Google colab to run in jupyter notebook (https://colab.research.google.com/) How to load data in Google Colab ?(https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)
# 6. The lab must be submitted on Google classroom. The code as well as the accompanying observations should be made part of the python notebook.
# 7. **Code Readability** is very important. Hence use self explanatory variable names and add comments to describe your approach wherever necessary.
# 8. You are expected to submit your **detailed inferences** and not just an error free code.
# 9. The lab is due on **March 20th 11.59pm**.
# 10. The lab should be completed **individually**. Students are expected to follow the **honor code** of the class.
#
# For any doubts regarding lab please mail to 2018csm1011@iitrpr.ac.in
#
#
# Below is the multi layer perceptron architechture used for implementation. Notations of the neural network are mentioned below :

# %% [markdown]
# ![MLP implementation diagram](pictures/mlp.png)

# %% [markdown]
# ## Implementation details :
#
# 1) In this lab you will be using MLP for classifying MNIST digits. a. Let us consider a MLP network with H hidden units, O outputs, and
# inputs of size D.
#
# 2) According to above diagram dimensions of network will be :
# ```
#  W - H * D+1   -- Weights from Input layer to Hidden layer
#  V - K * H+1   -- Weights from Hidden layer to Output layer
#  X - N * D+1   -- Weights of Input data
#  Y - N * K     -- Weights of Output label data
#  Z - H+1 * 1   -- Hidden layer Weights
#  O - K * 1     -- Output layer weights
# ```
# 3) Please note that +1 in above notations is to indicate bias term.
#
# 4) tanh is used as the activation function.
#
# 5) During forward pass will be :
#
# $\mathbf{z}=\tanh (\mathbf{W} \mathbf{x})$
#
# and $O_{i}=\frac{\exp v_{i}^{T} z}{\sum_{k=1}^{K} \exp v_{k}^{T} z}$
#
# Overall loss function will be :
#
# Total loss = $-\sum_{n=1}^{N} \sum_{i=1}^{K} y_{n i} \log O_{n i}$

# %% [markdown]
# 6) The dataset is included in zip file ("data.txt" and "label.txt"). Number of hidden layer units to be 500, learning rate is set to be 0.01.
#
# 7) Inorder to update the weights during back propogation we will modified version of stochastic gradient descent, where instead of updating weights after each data point, the updates are made once with batch of input data, Let batch size = 25. Number of epochs = 100.
#
# 8) Divide the data into train, validation, and test splits using a preset ratio. Please define the ratio you are using.
#
# 9) Please plot the below :
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]

# %% [markdown]
# # Note :
#
# 1) All weight update equations during back propogation should be done using $\textbf{Matrix operations}$ only (not for loops).
#
#  For example :
#
# ![MLP implementation diagram](pictures/equation.png)

# %% [markdown]
# # Maximum points : 90 points.
#
# 1) Derive the weight update equation for W in form of Matrix operations similar to V matrix operations defined above.(write in the jupyter notebook itself using Latex or image) - 10 pts
#
# ------
# ![Follow the Link, if not visible : https://drive.google.com/file/d/17x9yTZnEFxJDzXQIALAPMxlnQLsVieyO/view ](pictures/Derivation.jpg)
#
# -----
# 2) Splitting train, validation and test using preset ratio - 5 pts
#
# 3) Random weights assign to W,V values -  5 pts.
#
# 4) During Forward pass :
#
#        updating Z values - 5 pts.
#
#        updating O values - 5 pts.
#
#        Applying softmax values - 5pts.
#
#        Calculating error values - 5pts.
#
# 5) During backward pass : ( only matrix operations allowed)
#
#        Gradient between hidden to output - 10 pts.
#
#        Gradient betweem input to hidden - 15 pts.
#
# 6) Using batch size = 25 to update weights - 5 pts.
#
# 7) averaging over 5 runs - 5 pts.
#
# 8) Please plot the below : - 10pts.
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]
#
# 9) Discuss the observations from above plots. - 5pts.

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split as split
import numpy as np
import random

####################################################################################
# Derivative of weights as defined in Lab3.a	####################################
####################################################################################
####################################################################################

# Dimension of all the Matrices Used
# W - H * D+1   -- Weights from Input layer to Hidden layer
# V - K * H+1   -- Weights from Hidden layer to Output layer
# X - N * D+1   -- Weights of Input data
# Y - N * K     -- Weights of Output label data
# Z - H+1 * 1   -- Hidden layer Weights
# O - K * 1     -- Output layer weights


# Function to read data and store it in form of 2D array
def read_data(file_name) :
    data = np.loadtxt(file_name, delimiter=',')
    return data


# Implementation of Forward pass function
def forward_pass(data_points,W,V,Y) :
    # use compute_Z_values, compute_O_values, compute_softmax, calculate_error to compute error, O_softmax
    # During forward pass compute Z values, O_values, O_softmax, error
    # Insert code here

    z_values = compute_Z_values(W,data_points)
    o_values = compute_O_values (V, z_values)
    O_softmax = compute_softmax(o_values)
    error = calculate_error(O_softmax , Y)
    
    #return the error, O_softmax
    return error,O_softmax , z_values



''
# Implementation of Cross Entropy Error Function takes as input O_softmax, Y
def calculate_error(predictions, targets, epsilon=1e-10):
    # Caculate cross entropy error between output of softmax (predictions) , actual values (targets)
    #returns cross entropy error
    #Insert code here

    cross_entropy_error = -1 * np.sum(np.multiply(targets, np.log(predictions)))
    return cross_entropy_error


# Implementation of Softmax Error Function takes as input O
def compute_softmax(output_matrix) :
    # return output_matrix after apply softmax function ( hint: use np.exp function )
    y_length = 10

    #Insert code here
    exp_matrix = np.exp(output_matrix)
    exp_sum = np.sum(exp_matrix , axis = 1) # TODO
    soft_matrix = exp_matrix / exp_sum[:,None]

    # returns output_matrix
    return soft_matrix


# Implementation of Backward pass using Backpropagation Algorithm to calculate V_new, W_new, bias_v
def backward_pass(O_softmax,Y,V,Z,W,X,bias_z):
    # use gradient_hidden_to_output, gradient_input_to_hidden functions to compute V_new, bias_v, W_new 
    #Insert code here
    
     
    V_new, bias_v = gradient_hidden_to_output(O_softmax,Y,Z,bias_z)     
    W_new = gradient_input_to_hidden(O_softmax, Y, V ,Z, X)

    

    return  W_new,V_new,bias_v


#Implementation of Graident back propogation from Hidden to Input Layer
def gradient_hidden_to_output(O_softmax,Y,Z,bias_z) :
    # function to update V values using backpropogation using matrix operations.
    #Insert code here
    grad_loss_O = O_softmax - Y
    final_result_matrix =  np.matmul(np.transpose(grad_loss_O) , Z )  #No bias term   
    bias_v =  np.matmul(np.transpose(grad_loss_O) , np.ones( (25,1)) )
    
    return final_result_matrix,bias_v

#Implementation of Graident back propogation from Input to Hidden Layer
def gradient_input_to_hidden(O_softmax,Y,V,Z,X) :
    # function to update W values using backpropogation using only matrix operations.
    #Insert code here
    grad_loss_O = O_softmax - Y
    termA = np.matmul( grad_loss_O , V[:, :-1] )
    termB = 1 - np.multiply(np.tanh(Z) , np.tanh(Z))
    result_matrix = np.matmul ( np.transpose(np.multiply(termA, termB)) , X)
    # print(termA.shape)
    # returns updated W values
    return result_matrix



# Function to calculate Z values during forward pass
def compute_Z_values(weights,data_points) :
    # function to update Z during forward pass using matrix operations.
    #Insert code here
    z_values = np.tanh(np.matmul(data_points, np.transpose(weights)))
    
    #TODO : Doubt return 500 * 25 or 25 * 500
    
    
    return z_values


# Function to Calculate output matrix during forward pass
def compute_O_values(weights,z_values) :

    # function to update O during forward pass using matrix operations.
    #Insert code here

    z_values_biased = initilaise_weights(z_values)
    # print(z_values_biased.shape)
    o_values = np.matmul(z_values_biased, np.transpose(weights))

    
    return o_values



# Function to Intialise weights with bias term
def initilaise_weights(data) :
    # function to append bias term.
    # insert code here
    X,Y = data.shape
    # final_shape[1] = final_shape[1] + 1 
    final_data = np.ones((X,Y+1),np.float )
    final_data[:, :-1 ] = data
    return final_data



# To intiliase random weights to Matrices such as W, V
def random_weights(number_of_rows,number_of_columns) :
    # Function to assign random weights to W, V
    #Insert code here 
    new_data_shape = (number_of_rows, number_of_columns )
    new_data = np.random.random(new_data_shape)
    # return random weights with number_of_rows * number_of_columns
    # print(new_data)
    return new_data


# To divide the data into test train data
def train_test_split(X,Y,fraction) :
    # Function to divide train, validation and test data based on fraction. let fraction = 0.8 then train = 0.75, validation= 0.05 and test = 0.2 
    #Insert code here 
    data_train_x, test_data_x , data_train_y, test_data_y = split(X,Y , test_size=1-fraction)
    data_train_x, validation_data_x, data_train_y, validation_data_y = split(data_train_x, data_train_y,test_size=1-fraction )

    # return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y
    return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y


# Shuffle in same order for X,Y
def shuffle(a, b, seed):
   # to Shuffle in same order for X,Y based on seed
   #Insert code here
    rows = a.shape[0]
    column_a = a.shape[1]
    column_b = b.shape[1]
    combined = np.zeros((rows, column_a + column_b))
    combined[:, :column_a ] = a
    combined[: ,column_a : ] = b
    np.random.seed(seed)
    np.random.shuffle(combined)
    a = combined[:, :column_a  ]
    b = combined[: ,column_a  : ] 
    # return shuffled values a,b in same order
    return a,b


if __name__ == "__main__" :
    data = read_data("data.txt")
    Y = read_data("label.txt")
    X = initilaise_weights(data)
    W = random_weights(500,401)
    V = random_weights(10,501)
    Z = compute_Z_values(W,X[:25,:])
    O = compute_O_values(V,Z)
    bias_z = np.empty(shape=(25, 1))
    bias_z.fill(1.0)
    i=0
    learning_rate = 0.01
    train_test_fraction  = 0.8
    train_validation_split = 0.2
    train_data_x,train_data_y,validation_data_x,validation_data_y,test_data_x,test_data_y =train_test_split(X,Y,train_test_fraction)
    number_of_epocs=100
    train_error_epoch = []*(5*number_of_epocs)
    #X = train_data_x
    #Y = train_data_y
    #Dividing the data into training data and test data into 0.8 ratio same ration for train and validation data,values below correspond to 0.8 ratio
    train_data_len = 3200
    validation_data_len = 800
    test_data_len =1000
    validation_error_epoch = [] * (5*number_of_epocs)
    # Running for 5 trails using 100 Epocs and Batch size = 25
    batch_size = 25
    print("Started calculating Training error in 5 Trails for each epoch with Batch size = 25 ")
    print("Started calculating Validation error in 5 Trails for each epoch with Batch size = 25 ")
    # Different trails are performed for 5 times.
    # 5 different trails
    for k in range(5) :
        W = random_weights(500, 401)
        V = random_weights(10, 501)
        error_train=0
        error_validation = 0
        # Randomising the data
        seed = random.randint(10000,10000000)
        X,Y = shuffle(X,Y,seed) 
        print("Training Error for 100th epoch for Trail Number : "+str(k+1))
        for j in range(number_of_epocs) :
            i=0
            count=0
            error_train = 0.0
            error_validation = 0.0
            #X,Y = shuffle(X,Y,12345)
            while i < (train_data_len)  :
                i1=i
                # Batch size is 25
                i= i+25
                # Update O_Values and
                # Modified Forward _pass function to update Z values on every pass 
                error,O_softmax , Z =forward_pass(X[i1:i, :], W, V, Y[i1:i, :])
                W_new,V_new,bias_v=backward_pass(O_softmax,Y[i1:i,:],V,Z,W,X[i1:i,:],bias_z)
                #print(W_new.shape)
                W = W - (learning_rate/25)*W_new
                #print(W)
                # print(bias_v.shape, V_new.shape)
                V_new = np.append(learning_rate*bias_v,V_new,axis=1)
                V = V - (learning_rate/25)*V_new
                error_train+= error
                count+=1
                #print(error1)
                #print(V.shape)
            #print(error)
            #print(j)
            error, O_softmax,_ = forward_pass(X[0:3200, :], W, V, Y[0 : 3200, :])
            error1, O_softmax,_ = forward_pass(X[3200:4000, :], W, V, Y[3200:4000, :])
            error_validation = error1
            count = train_data_len/batch_size
            count1= validation_data_len/batch_size
            error_train = error_train/count
            print("Training error after  epoch : "+str(j+1)+" here every batch size = 25")
            print(error_train)
            print("Validation error after  epoch : "+str(j+1)+" here batch size = 25")
            print(error_validation)
            train_error_epoch.append(error_train)
            validation_error_epoch.append(error_validation)
    print("\n")
    print("Final Training Errors after 5 trails and 100 Epocs : ")
    print(train_error_epoch)
    print("\n")
    print("Final Validation Errors after 5 trails and 100 Epocs : ")
    print(validation_error_epoch)
    mean_training = []
    variance_training = []
    mean_validation = []
    variance_validation = []
    train_error_epoch = np.reshape(train_error_epoch,(5,number_of_epocs))
    validation_error_epoch = np.reshape(validation_error_epoch,(5,number_of_epocs))
    mean_training = np.mean(train_error_epoch, axis=0)
    mean_validation = np.mean(validation_error_epoch,axis=0)
    variance_training = np.var(train_error_epoch,axis=0)
    variance_validation = np.var(validation_error_epoch,axis=0)
    mean_training = np.reshape(mean_training,(number_of_epocs,))
    mean_validation = np.reshape(mean_validation, (number_of_epocs))
    variance_training = np.reshape(variance_training,(number_of_epocs,))
    variance_validation = np.reshape(variance_validation,(number_of_epocs,))
    epochs = []
    for i in range(1,number_of_epocs+1) :
        epochs.append(i)
    print("\n")
    print("Plots are started to Generate In Figures Folder : ")
    plt.plot(epochs,mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    #plt.title("Plot for Training Error Vs Epochs")
    location = "./figures/lab3.a_TrainingError" + ".png"
    #plt.savefig(location)
    #plt.close()
    plt.plot(epochs, mean_validation,color='blue', label='Validation')
    plt.ylabel("Training,Validation Error values")
    plt.title("Plot for Training,Validation Error Vs Epochs")
    plt.legend(loc='best')
    location = "./figures/lab3.a_TrainingAndValidationError" + ".png"
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0145,0.01465)
    plt.plot(epochs, mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel("Mean Training Error values")
    plt.title("Plot for Mean Training Error Vs Epochs")
    location = "./figures/lab3.a_MeanTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0133, 0.134)
    plt.plot(epochs, mean_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel(" Mean Validation Error values")
    plt.title("Plot for Mean Validation Error Vs Epochs")
    location = "./figures/lab3.a_MeanValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000240, 0.000242)
    plt.plot(epochs, variance_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel(" Variance Training Error values")
    plt.title("Plot for Variance Training Error Vs Epochs")
    location = "./figures/lab3.a_VarianceTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000210, 0.000211)
    plt.plot(epochs, variance_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel("Variance Validation Error values")
    plt.title("Plot for Variance Validation Error Vs Epochs")
    location = "./figures/lab3.a_VarianceValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    print("\n")
    print("Plots are Generated Successfully In Figures folder")
# Out:
# Started calculating Training error in 5 Trails for each epoch with Batch size = 25
# Started calculating Validation error in 5 Trails for each epoch with Batch size = 25
# Training Error for 100th epoch for Trail Number : 1
# Training error after  epoch : 1 here every batch size = 25
# 62.3457837674732
# Validation error after  epoch : 1 here batch size = 25
# 1935.7913784426432
# Training error after  epoch : 2 here every batch size = 25
# 59.06188348545383
# Validation error after  epoch : 2 here batch size = 25
# 1935.7913711171036
# Training error after  epoch : 3 here every batch size = 25
# 59.061882925765204
# Validation error after  epoch : 3 here batch size = 25
# 1935.79136345994
# Training error after  epoch : 4 here every batch size = 25
# 59.06188234866398
# Validation error after  epoch : 4 here batch size = 25
# 1935.7913549942505
# Training error after  epoch : 5 here every batch size = 25
# 59.06188173503599
# Validation error after  epoch : 5 here batch size = 25
# 1935.791345176319
# Training error after  epoch : 6 here every batch size = 25
# 59.06188106370736
# Validation error after  epoch : 6 here batch size = 25
# 1935.7913333448337
# Training error after  epoch : 7 here every batch size = 25
# 59.06188031006082
# Validation error after  epoch : 7 here batch size = 25
# 1935.7913186575202
# Training error after  epoch : 8 here every batch size = 25
# 59.06187944430622
# Validation error after  epoch : 8 here batch size = 25
# 1935.7913000075173
# Training error after  epoch : 9 here every batch size = 25
# 59.061878429197264
# Validation error after  epoch : 9 here batch size = 25
# 1935.7912759092349
# Training error after  epoch : 10 here every batch size = 25
# 59.06187721689739
# Validation error after  epoch : 10 here batch size = 25
# 1935.7912443392886
# Training error after  epoch : 11 here every batch size = 25
# 59.061875744539655
# Validation error after  epoch : 11 here batch size = 25
# 1935.7912025111214
# Training error after  epoch : 12 here every batch size = 25
# 59.06187392778859
# Validation error after  epoch : 12 here batch size = 25
# 1935.7911465530283
# Training error after  epoch : 13 here every batch size = 25
# 59.06187165129382
# Validation error after  epoch : 13 here batch size = 25
# 1935.791071042812
# Training error after  epoch : 14 here every batch size = 25
# 59.06186875425932
# Validation error after  epoch : 14 here batch size = 25
# 1935.7909683300365
# Training error after  epoch : 15 here every batch size = 25
# 59.06186500820806
# Validation error after  epoch : 15 here batch size = 25
# 1935.7908275394022
# Training error after  epoch : 16 here every batch size = 25
# 59.06186008207321
# Validation error after  epoch : 16 here batch size = 25
# 1935.790633091092
# Training error after  epoch : 17 here every batch size = 25
# 59.06185348636407
# Validation error after  epoch : 17 here batch size = 25
# 1935.7903624796072
# Training error after  epoch : 18 here every batch size = 25
# 59.06184448216237
# Validation error after  epoch : 18 here batch size = 25
# 1935.7899828977545
# Training error after  epoch : 19 here every batch size = 25
# 59.06183192993866
# Validation error after  epoch : 19 here batch size = 25
# 1935.78944603223
# Training error after  epoch : 20 here every batch size = 25
# 59.06181403346267
# Validation error after  epoch : 20 here batch size = 25
# 1935.7886799074536
# Training error after  epoch : 21 here every batch size = 25
# 59.06178789727654
# Validation error after  epoch : 21 here batch size = 25
# 1935.7875758617747
# Training error after  epoch : 22 here every batch size = 25
# 59.06174874623028
# Validation error after  epoch : 22 here batch size = 25
# 1935.785967297331
# Training error after  epoch : 23 here every batch size = 25
# 59.061688519950145
# Validation error after  epoch : 23 here batch size = 25
# 1935.783594151877
# Training error after  epoch : 24 here every batch size = 25
# 59.06159328726797
# Validation error after  epoch : 24 here batch size = 25
# 1935.7800418325103
# Training error after  epoch : 25 here every batch size = 25
# 59.06143838693928
# Validation error after  epoch : 25 here batch size = 25
# 1935.7746329192494
# Training error after  epoch : 26 here every batch size = 25
# 59.0611790982972
# Validation error after  epoch : 26 here batch size = 25
# 1935.7662280999723
# Training error after  epoch : 27 here every batch size = 25
# 59.06073235054919
# Validation error after  epoch : 27 here batch size = 25
# 1935.752844610804
# Training error after  epoch : 28 here every batch size = 25
# 59.05994013818117
# Validation error after  epoch : 28 here batch size = 25
# 1935.730887412019
# Training error after  epoch : 29 here every batch size = 25
# 59.058495068428265
# Validation error after  epoch : 29 here batch size = 25
# 1935.693504512984
# Training error after  epoch : 30 here every batch size = 25
# 59.05578732386602
# Validation error after  epoch : 30 here batch size = 25
# 1935.6268179544948
# Training error after  epoch : 31 here every batch size = 25
# 59.05059165059715
# Validation error after  epoch : 31 here batch size = 25
# 1935.500680007724
# Training error after  epoch : 32 here every batch size = 25
# 59.04046775199933
# Validation error after  epoch : 32 here batch size = 25
# 1935.2453295622845
# Training error after  epoch : 33 here every batch size = 25
# 59.02114242346771
# Validation error after  epoch : 33 here batch size = 25
# 1934.699771253349
# Training error after  epoch : 34 here every batch size = 25
# 58.98680133969262
# Validation error after  epoch : 34 here batch size = 25
# 1933.569826929322
# Training error after  epoch : 35 here every batch size = 25
# 58.929177182677066
# Validation error after  epoch : 35 here batch size = 25
# 1931.656116481691
# Training error after  epoch : 36 here every batch size = 25
# 58.836500567080094
# Validation error after  epoch : 36 here batch size = 25
# 1928.8862983685258
# Training error after  epoch : 37 here every batch size = 25
# 58.69322998510932
# Validation error after  epoch : 37 here batch size = 25
# 1924.1033565836678
# Training error after  epoch : 38 here every batch size = 25
# 58.47521954731209
# Validation error after  epoch : 38 here batch size = 25
# 1916.1269196521275
# Training error after  epoch : 39 here every batch size = 25
# 58.152851057133184
# Validation error after  epoch : 39 here batch size = 25
# 1903.5257627463943
# Training error after  epoch : 40 here every batch size = 25
# 57.6992765775301
# Validation error after  epoch : 40 here batch size = 25
# 1885.668718344165
# Training error after  epoch : 41 here every batch size = 25
# 57.08452258075084
# Validation error after  epoch : 41 here batch size = 25
# 1862.103664340826
# Training error after  epoch : 42 here every batch size = 25
# 56.327115950062
# Validation error after  epoch : 42 here batch size = 25
# 1833.5285027809468
# Training error after  epoch : 43 here every batch size = 25
# 55.43282921101497
# Validation error after  epoch : 43 here batch size = 25
# 1801.7562606177016
# Training error after  epoch : 44 here every batch size = 25
# 54.43684266673143
# Validation error after  epoch : 44 here batch size = 25
# 1768.3687957704037
# Training error after  epoch : 45 here every batch size = 25
# 53.35312575927818
# Validation error after  epoch : 45 here batch size = 25
# 1733.4645323192658
# Training error after  epoch : 46 here every batch size = 25
# 52.226163784805784
# Validation error after  epoch : 46 here batch size = 25
# 1697.5768630167186
# Training error after  epoch : 47 here every batch size = 25
# 51.084733371420214
# Validation error after  epoch : 47 here batch size = 25
# 1662.6580446409564
# Training error after  epoch : 48 here every batch size = 25
# 49.934553875869824
# Validation error after  epoch : 48 here batch size = 25
# 1628.595236427009
# Training error after  epoch : 49 here every batch size = 25
# 48.78939709969528
# Validation error after  epoch : 49 here batch size = 25
# 1595.1803875009132
# Training error after  epoch : 50 here every batch size = 25
# 47.65232926331409
# Validation error after  epoch : 50 here batch size = 25
# 1563.2130537406163
# Training error after  epoch : 51 here every batch size = 25
# 46.533473591729184
# Validation error after  epoch : 51 here batch size = 25
# 1533.6306350239793
# Training error after  epoch : 52 here every batch size = 25
# 45.4606381371853
# Validation error after  epoch : 52 here batch size = 25
# 1505.6802263247596
# Training error after  epoch : 53 here every batch size = 25
# 44.45444644614465
# Validation error after  epoch : 53 here batch size = 25
# 1478.1276430233715
# Training error after  epoch : 54 here every batch size = 25
# 43.506607453597006
# Validation error after  epoch : 54 here batch size = 25
# 1449.466814507337
# Training error after  epoch : 55 here every batch size = 25
# 42.59895901357355
# Validation error after  epoch : 55 here batch size = 25
# 1420.2846386134906
# Training error after  epoch : 56 here every batch size = 25
# 41.72021293820769
# Validation error after  epoch : 56 here batch size = 25
# 1391.380107607562
# Training error after  epoch : 57 here every batch size = 25
# 40.870576388165304
# Validation error after  epoch : 57 here batch size = 25
# 1363.035390592675
# Training error after  epoch : 58 here every batch size = 25
# 40.059268090984645
# Validation error after  epoch : 58 here batch size = 25
# 1335.5073359434602
# Training error after  epoch : 59 here every batch size = 25
# 39.290719721054096
# Validation error after  epoch : 59 here batch size = 25
# 1308.3341714392532
# Training error after  epoch : 60 here every batch size = 25
# 38.55677319307354
# Validation error after  epoch : 60 here batch size = 25
# 1281.3840717965095
# Training error after  epoch : 61 here every batch size = 25
# 37.843032195752606
# Validation error after  epoch : 61 here batch size = 25
# 1254.7386969995605
# Training error after  epoch : 62 here every batch size = 25
# 37.141961508204055
# Validation error after  epoch : 62 here batch size = 25
# 1228.4156277950328
# Training error after  epoch : 63 here every batch size = 25
# 36.45444075967677
# Validation error after  epoch : 63 here batch size = 25
# 1202.6232408096234
# Training error after  epoch : 64 here every batch size = 25
# 35.782880733564255
# Validation error after  epoch : 64 here batch size = 25
# 1177.6651319730704
# Training error after  epoch : 65 here every batch size = 25
# 35.128239546808565
# Validation error after  epoch : 65 here batch size = 25
# 1153.6916782966555
# Training error after  epoch : 66 here every batch size = 25
# 34.4923645552189
# Validation error after  epoch : 66 here batch size = 25
# 1130.6615440479193
# Training error after  epoch : 67 here every batch size = 25
# 33.878090065413254
# Validation error after  epoch : 67 here batch size = 25
# 1108.4579424239591
# Training error after  epoch : 68 here every batch size = 25
# 33.28511117504497
# Validation error after  epoch : 68 here batch size = 25
# 1086.9586683784055
# Training error after  epoch : 69 here every batch size = 25
# 32.713418092808816
# Validation error after  epoch : 69 here batch size = 25
# 1065.9880163879416
# Training error after  epoch : 70 here every batch size = 25
# 32.17077687864714
# Validation error after  epoch : 70 here batch size = 25
# 1045.3452144953994
# Training error after  epoch : 71 here every batch size = 25
# 31.666854806945008
# Validation error after  epoch : 71 here batch size = 25
# 1024.889629366542
# Training error after  epoch : 72 here every batch size = 25
# 31.20825578662071
# Validation error after  epoch : 72 here batch size = 25
# 1004.6567882741444
# Training error after  epoch : 73 here every batch size = 25
# 30.796899768668027
# Validation error after  epoch : 73 here batch size = 25
# 984.8232376584829
# Training error after  epoch : 74 here every batch size = 25
# 30.427177467751115
# Validation error after  epoch : 74 here batch size = 25
# 965.5663743155089
# Training error after  epoch : 75 here every batch size = 25
# 30.090546260853145
# Validation error after  epoch : 75 here batch size = 25
# 947.0637242466315
# Training error after  epoch : 76 here every batch size = 25
# 29.780458152193
# Validation error after  epoch : 76 here batch size = 25
# 929.6601821828461
# Training error after  epoch : 77 here every batch size = 25
# 29.49409977278614
# Validation error after  epoch : 77 here batch size = 25
# 914.0573713681056
# Training error after  epoch : 78 here every batch size = 25
# 29.228991911169825
# Validation error after  epoch : 78 here batch size = 25
# 900.6637920603439
# Training error after  epoch : 79 here every batch size = 25
# 28.981703577684414
# Validation error after  epoch : 79 here batch size = 25
# 889.3084059469993
# Training error after  epoch : 80 here every batch size = 25
# 28.751930396868936
# Validation error after  epoch : 80 here batch size = 25
# 879.5482688771884
# Training error after  epoch : 81 here every batch size = 25
# 28.540142432300687
# Validation error after  epoch : 81 here batch size = 25
# 870.7707978024846
# Training error after  epoch : 82 here every batch size = 25
# 28.34614169637409
# Validation error after  epoch : 82 here batch size = 25
# 862.4706646226339
# Training error after  epoch : 83 here every batch size = 25
# 28.16863062244446
# Validation error after  epoch : 83 here batch size = 25
# 854.4447769004371
# Training error after  epoch : 84 here every batch size = 25
# 28.00381666209166
# Validation error after  epoch : 84 here batch size = 25
# 846.7416375168739
# Training error after  epoch : 85 here every batch size = 25
# 27.848051057580307
# Validation error after  epoch : 85 here batch size = 25
# 839.4888607403193
# Training error after  epoch : 86 here every batch size = 25
# 27.70275050889682
# Validation error after  epoch : 86 here batch size = 25
# 832.7705211189337
# Training error after  epoch : 87 here every batch size = 25
# 27.57277841418583
# Validation error after  epoch : 87 here batch size = 25
# 826.4759941274317
# Training error after  epoch : 88 here every batch size = 25
# 27.459897294403447
# Validation error after  epoch : 88 here batch size = 25
# 820.3101548985492
# Training error after  epoch : 89 here every batch size = 25
# 27.361978911098987
# Validation error after  epoch : 89 here batch size = 25
# 814.0707374707999
# Training error after  epoch : 90 here every batch size = 25
# 27.27695045538038
# Validation error after  epoch : 90 here batch size = 25
# 807.78823908498
# Training error after  epoch : 91 here every batch size = 25
# 27.205405643962294
# Validation error after  epoch : 91 here batch size = 25
# 801.7172761046344
# Training error after  epoch : 92 here every batch size = 25
# 27.15193799114239
# Validation error after  epoch : 92 here batch size = 25
# 796.2046471083913
# Training error after  epoch : 93 here every batch size = 25
# 27.120396219967958
# Validation error after  epoch : 93 here batch size = 25
# 791.4836545690621
# Training error after  epoch : 94 here every batch size = 25
# 27.10853725950485
# Validation error after  epoch : 94 here batch size = 25
# 787.6122625181351
# Training error after  epoch : 95 here every batch size = 25
# 27.109420509534793
# Validation error after  epoch : 95 here batch size = 25
# 784.5495884482455
# Training error after  epoch : 96 here every batch size = 25
# 27.116819509013578
# Validation error after  epoch : 96 here batch size = 25
# 782.2330380276966
# Training error after  epoch : 97 here every batch size = 25
# 27.129020774180315
# Validation error after  epoch : 97 here batch size = 25
# 780.59811175305
# Training error after  epoch : 98 here every batch size = 25
# 27.14555144418386
# Validation error after  epoch : 98 here batch size = 25
# 779.5556951400474
# Training error after  epoch : 99 here every batch size = 25
# 27.163705830415804
# Validation error after  epoch : 99 here batch size = 25
# 779.0218467975174
# Training error after  epoch : 100 here every batch size = 25
# 27.1807934468786
# Validation error after  epoch : 100 here batch size = 25
# 778.9038922503171
# Training Error for 100th epoch for Trail Number : 2
# Training error after  epoch : 1 here every batch size = 25
# 63.39119142216914
# Validation error after  epoch : 1 here batch size = 25
# 1892.0706374710157
# Training error after  epoch : 2 here every batch size = 25
# 58.95747615909826
# Validation error after  epoch : 2 here batch size = 25
# 1892.0706164900125
# Training error after  epoch : 3 here every batch size = 25
# 58.957474378990334
# Validation error after  epoch : 3 here batch size = 25
# 1892.0705949655437
# Training error after  epoch : 4 here every batch size = 25
# 58.957472528697934
# Validation error after  epoch : 4 here batch size = 25
# 1892.0705717377755
# Training error after  epoch : 5 here every batch size = 25
# 58.957470555303175
# Validation error after  epoch : 5 here batch size = 25
# 1892.0705454569315
# Training error after  epoch : 6 here every batch size = 25
# 58.957468398085
# Validation error after  epoch : 6 here batch size = 25
# 1892.070514445325
# Training error after  epoch : 7 here every batch size = 25
# 58.957465984413446
# Validation error after  epoch : 7 here batch size = 25
# 1892.0704765068494
# Training error after  epoch : 8 here every batch size = 25
# 58.95746322425022
# Validation error after  epoch : 8 here batch size = 25
# 1892.0704286497357
# Training error after  epoch : 9 here every batch size = 25
# 58.95746000249228
# Validation error after  epoch : 9 here batch size = 25
# 1892.0703666712586
# Training error after  epoch : 10 here every batch size = 25
# 58.957456167981256
# Validation error after  epoch : 10 here batch size = 25
# 1892.07028452114
# Training error after  epoch : 11 here every batch size = 25
# 58.95745151733491
# Validation error after  epoch : 11 here batch size = 25
# 1892.0701733088008
# Training error after  epoch : 12 here every batch size = 25
# 58.95744577063772
# Validation error after  epoch : 12 here batch size = 25
# 1892.0700197335866
# Training error after  epoch : 13 here every batch size = 25
# 58.95743853416958
# Validation error after  epoch : 13 here batch size = 25
# 1892.0698035745636
# Training error after  epoch : 14 here every batch size = 25
# 58.9574292422126
# Validation error after  epoch : 14 here batch size = 25
# 1892.0694936342143
# Training error after  epoch : 15 here every batch size = 25
# 58.95741706459769
# Validation error after  epoch : 15 here batch size = 25
# 1892.0690411244927
# Training error after  epoch : 16 here every batch size = 25
# 58.95740075737092
# Validation error after  epoch : 16 here batch size = 25
# 1892.0683687931676
# Training error after  epoch : 17 here every batch size = 25
# 58.95737841772596
# Validation error after  epoch : 17 here batch size = 25
# 1892.067352914562
# Training error after  epoch : 18 here every batch size = 25
# 58.957347075694344
# Validation error after  epoch : 18 here batch size = 25
# 1892.0657932701433
# Training error after  epoch : 19 here every batch size = 25
# 58.95730200404442
# Validation error after  epoch : 19 here batch size = 25
# 1892.0633628509981
# Training error after  epoch : 20 here every batch size = 25
# 58.95723553629157
# Validation error after  epoch : 20 here batch size = 25
# 1892.05952330928
# Training error after  epoch : 21 here every batch size = 25
# 58.95713501801625
# Validation error after  epoch : 21 here batch size = 25
# 1892.0533828144273
# Training error after  epoch : 22 here every batch size = 25
# 58.95697922134496
# Validation error after  epoch : 22 here batch size = 25
# 1892.043458292839
# Training error after  epoch : 23 here every batch size = 25
# 58.95673203071862
# Validation error after  epoch : 23 here batch size = 25
# 1892.027283290834
# Training error after  epoch : 24 here every batch size = 25
# 58.9563313193778
# Validation error after  epoch : 24 here batch size = 25
# 1892.0007800348822
# Training error after  epoch : 25 here every batch size = 25
# 58.955669538226196
# Validation error after  epoch : 25 here batch size = 25
# 1891.95730875258
# Training error after  epoch : 26 here every batch size = 25
# 58.95456071359841
# Validation error after  epoch : 26 here batch size = 25
# 1891.886367217388
# Training error after  epoch : 27 here every batch size = 25
# 58.952687320714595
# Validation error after  epoch : 27 here batch size = 25
# 1891.7720941820298
# Training error after  epoch : 28 here every batch size = 25
# 58.94952350447964
# Validation error after  epoch : 28 here batch size = 25
# 1891.5918825724061
# Training error after  epoch : 29 here every batch size = 25
# 58.9442471970472
# Validation error after  epoch : 29 here batch size = 25
# 1891.31470118721
# Training error after  epoch : 30 here every batch size = 25
# 58.93569474145995
# Validation error after  epoch : 30 here batch size = 25
# 1890.8965827096756
# Training error after  epoch : 31 here every batch size = 25
# 58.922447852244865
# Validation error after  epoch : 31 here batch size = 25
# 1890.2731450119359
# Training error after  epoch : 32 here every batch size = 25
# 58.90299642719237
# Validation error after  epoch : 32 here batch size = 25
# 1889.365057232058
# Training error after  epoch : 33 here every batch size = 25
# 58.875630603814706
# Validation error after  epoch : 33 here batch size = 25
# 1888.107453335289
# Training error after  epoch : 34 here every batch size = 25
# 58.83805078934997
# Validation error after  epoch : 34 here batch size = 25
# 1886.462060117843
# Training error after  epoch : 35 here every batch size = 25
# 58.78681055496026
# Validation error after  epoch : 35 here batch size = 25
# 1884.371024972827
# Training error after  epoch : 36 here every batch size = 25
# 58.71632405462707
# Validation error after  epoch : 36 here batch size = 25
# 1881.5925626496823
# Training error after  epoch : 37 here every batch size = 25
# 58.618982984955366
# Validation error after  epoch : 37 here batch size = 25
# 1877.5401371736439
# Training error after  epoch : 38 here every batch size = 25
# 58.48191261336032
# Validation error after  epoch : 38 here batch size = 25
# 1871.8314204097146
# Training error after  epoch : 39 here every batch size = 25
# 58.28307108039368
# Validation error after  epoch : 39 here batch size = 25
# 1864.3277459172718
# Training error after  epoch : 40 here every batch size = 25
# 58.01164840614641
# Validation error after  epoch : 40 here batch size = 25
# 1854.0380646787605
# Training error after  epoch : 41 here every batch size = 25
# 57.67879559163741
# Validation error after  epoch : 41 here batch size = 25
# 1840.0181001909195
# Training error after  epoch : 42 here every batch size = 25
# 57.29706155088787
# Validation error after  epoch : 42 here batch size = 25
# 1822.2204379645607
# Training error after  epoch : 43 here every batch size = 25
# 56.81830741489744
# Validation error after  epoch : 43 here batch size = 25
# 1800.833091893613
# Training error after  epoch : 44 here every batch size = 25
# 56.18979208638056
# Validation error after  epoch : 44 here batch size = 25
# 1776.2115046633817
# Training error after  epoch : 45 here every batch size = 25
# 55.42704861821652
# Validation error after  epoch : 45 here batch size = 25
# 1750.1089938452549
# Training error after  epoch : 46 here every batch size = 25
# 54.54319194885584
# Validation error after  epoch : 46 here batch size = 25
# 1723.0090852038747
# Training error after  epoch : 47 here every batch size = 25
# 53.56945418509602
# Validation error after  epoch : 47 here batch size = 25
# 1695.2314614648967
# Training error after  epoch : 48 here every batch size = 25
# 52.559566430476906
# Validation error after  epoch : 48 here batch size = 25
# 1665.5032324724416
# Training error after  epoch : 49 here every batch size = 25
# 51.533365542380025
# Validation error after  epoch : 49 here batch size = 25
# 1632.253361676179
# Training error after  epoch : 50 here every batch size = 25
# 50.50945689559893
# Validation error after  epoch : 50 here batch size = 25
# 1597.938678947085
# Training error after  epoch : 51 here every batch size = 25
# 49.50172640010065
# Validation error after  epoch : 51 here batch size = 25
# 1564.7275610731103
# Training error after  epoch : 52 here every batch size = 25
# 48.504763048783914
# Validation error after  epoch : 52 here batch size = 25
# 1532.575748242176
# Training error after  epoch : 53 here every batch size = 25
# 47.48882955264947
# Validation error after  epoch : 53 here batch size = 25
# 1500.09580357287
# Training error after  epoch : 54 here every batch size = 25
# 46.431195418700035
# Validation error after  epoch : 54 here batch size = 25
# 1466.9524241194235
# Training error after  epoch : 55 here every batch size = 25
# 45.34820159737107
# Validation error after  epoch : 55 here batch size = 25
# 1432.9628920994687
# Training error after  epoch : 56 here every batch size = 25
# 44.26500957768039
# Validation error after  epoch : 56 here batch size = 25
# 1398.5088168695984
# Training error after  epoch : 57 here every batch size = 25
# 43.19402382588912
# Validation error after  epoch : 57 here batch size = 25
# 1365.6058535544853
# Training error after  epoch : 58 here every batch size = 25
# 42.14388137866686
# Validation error after  epoch : 58 here batch size = 25
# 1334.916785517537
# Training error after  epoch : 59 here every batch size = 25
# 41.12558217872428
# Validation error after  epoch : 59 here batch size = 25
# 1306.027741905672
# Training error after  epoch : 60 here every batch size = 25
# 40.16125044367022
# Validation error after  epoch : 60 here batch size = 25
# 1278.6886757610573
# Training error after  epoch : 61 here every batch size = 25
# 39.25922675584082
# Validation error after  epoch : 61 here batch size = 25
# 1252.8381873208423
# Training error after  epoch : 62 here every batch size = 25
# 38.4102073054679
# Validation error after  epoch : 62 here batch size = 25
# 1227.6436194467478
# Training error after  epoch : 63 here every batch size = 25
# 37.601806516713204
# Validation error after  epoch : 63 here batch size = 25
# 1202.307440510111
# Training error after  epoch : 64 here every batch size = 25
# 36.829549155976636
# Validation error after  epoch : 64 here batch size = 25
# 1177.3702742514984
# Training error after  epoch : 65 here every batch size = 25
# 36.09363289445415
# Validation error after  epoch : 65 here batch size = 25
# 1153.668245492573
# Training error after  epoch : 66 here every batch size = 25
# 35.3921296063684
# Validation error after  epoch : 66 here batch size = 25
# 1131.4723921094032
# Training error after  epoch : 67 here every batch size = 25
# 34.716386610014865
# Validation error after  epoch : 67 here batch size = 25
# 1110.2651970006336
# Training error after  epoch : 68 here every batch size = 25
# 34.059542356981716
# Validation error after  epoch : 68 here batch size = 25
# 1089.3981596428648
# Training error after  epoch : 69 here every batch size = 25
# 33.42130739152712
# Validation error after  epoch : 69 here batch size = 25
# 1068.8047019650758
# Training error after  epoch : 70 here every batch size = 25
# 32.80694791636485
# Validation error after  epoch : 70 here batch size = 25
# 1049.0093176449204
# Training error after  epoch : 71 here every batch size = 25
# 32.22679325545284
# Validation error after  epoch : 71 here batch size = 25
# 1030.3747881391291
# Training error after  epoch : 72 here every batch size = 25
# 31.693168555303245
# Validation error after  epoch : 72 here batch size = 25
# 1012.9123031529696
# Training error after  epoch : 73 here every batch size = 25
# 31.20676736230492
# Validation error after  epoch : 73 here batch size = 25
# 996.3547114776736
# Training error after  epoch : 74 here every batch size = 25
# 30.755164621851574
# Validation error after  epoch : 74 here batch size = 25
# 980.5957026583914
# Training error after  epoch : 75 here every batch size = 25
# 30.327899982642972
# Validation error after  epoch : 75 here batch size = 25
# 965.908796985478
# Training error after  epoch : 76 here every batch size = 25
# 29.91653861482085
# Validation error after  epoch : 76 here batch size = 25
# 952.5697362722392
# Training error after  epoch : 77 here every batch size = 25
# 29.519227012027695
# Validation error after  epoch : 77 here batch size = 25
# 940.678176489464
# Training error after  epoch : 78 here every batch size = 25
# 29.14722071304041
# Validation error after  epoch : 78 here batch size = 25
# 930.0056685242524
# Training error after  epoch : 79 here every batch size = 25
# 28.80397557445063
# Validation error after  epoch : 79 here batch size = 25
# 920.1777521949066
# Training error after  epoch : 80 here every batch size = 25
# 28.475920406208054
# Validation error after  epoch : 80 here batch size = 25
# 911.0765842754556
# Training error after  epoch : 81 here every batch size = 25
# 28.15326773792613
# Validation error after  epoch : 81 here batch size = 25
# 903.0345288477515
# Training error after  epoch : 82 here every batch size = 25
# 27.840056637222414
# Validation error after  epoch : 82 here batch size = 25
# 896.4300237949808
# Training error after  epoch : 83 here every batch size = 25
# 27.545078418669206
# Validation error after  epoch : 83 here batch size = 25
# 891.2837004785715
# Training error after  epoch : 84 here every batch size = 25
# 27.270138956093437
# Validation error after  epoch : 84 here batch size = 25
# 887.3170777359892
# Training error after  epoch : 85 here every batch size = 25
# 27.018133467534664
# Validation error after  epoch : 85 here batch size = 25
# 884.1751751933882
# Training error after  epoch : 86 here every batch size = 25
# 26.790124412868423
# Validation error after  epoch : 86 here batch size = 25
# 881.7358811701695
# Training error after  epoch : 87 here every batch size = 25
# 26.585328306597006
# Validation error after  epoch : 87 here batch size = 25
# 880.1306028106945
# Training error after  epoch : 88 here every batch size = 25
# 26.40444969643509
# Validation error after  epoch : 88 here batch size = 25
# 879.5521532449703
# Training error after  epoch : 89 here every batch size = 25
# 26.246868374411193
# Validation error after  epoch : 89 here batch size = 25
# 880.022331961611
# Training error after  epoch : 90 here every batch size = 25
# 26.113034098369518
# Validation error after  epoch : 90 here batch size = 25
# 881.3787356776261
# Training error after  epoch : 91 here every batch size = 25
# 26.006913719011795
# Validation error after  epoch : 91 here batch size = 25
# 883.4090407562599
# Training error after  epoch : 92 here every batch size = 25
# 25.931388177783553
# Validation error after  epoch : 92 here batch size = 25
# 885.9452421526863
# Training error after  epoch : 93 here every batch size = 25
# 25.884582999194002
# Validation error after  epoch : 93 here batch size = 25
# 888.8711394904703
# Training error after  epoch : 94 here every batch size = 25
# 25.861214578555376
# Validation error after  epoch : 94 here batch size = 25
# 892.0745927678308
# Training error after  epoch : 95 here every batch size = 25
# 25.85561508008083
# Validation error after  epoch : 95 here batch size = 25
# 895.4550916388285
# Training error after  epoch : 96 here every batch size = 25
# 25.86507418311885
# Validation error after  epoch : 96 here batch size = 25
# 899.0382273665391
# Training error after  epoch : 97 here every batch size = 25
# 25.890366854213237
# Validation error after  epoch : 97 here batch size = 25
# 902.9992625208895
# Training error after  epoch : 98 here every batch size = 25
# 25.935669394188004
# Validation error after  epoch : 98 here batch size = 25
# 907.4927723609784
# Training error after  epoch : 99 here every batch size = 25
# 26.002666403062694
# Validation error after  epoch : 99 here batch size = 25
# 912.4695195563007
# Training error after  epoch : 100 here every batch size = 25
# 26.085590433882377
# Validation error after  epoch : 100 here batch size = 25
# 917.7766383246208
# Training Error for 100th epoch for Trail Number : 3
# Training error after  epoch : 1 here every batch size = 25
# 70.0779121046555
# Validation error after  epoch : 1 here batch size = 25
# 1896.9594859942372
# Training error after  epoch : 2 here every batch size = 25
# 59.027175397882885
# Validation error after  epoch : 2 here batch size = 25
# 1896.9594812657788
# Training error after  epoch : 3 here every batch size = 25
# 59.02717437185014
# Validation error after  epoch : 3 here batch size = 25
# 1896.9594763038242
# Training error after  epoch : 4 here every batch size = 25
# 59.02717335639018
# Validation error after  epoch : 4 here batch size = 25
# 1896.9594708688574
# Training error after  epoch : 5 here every batch size = 25
# 59.027172315491846
# Validation error after  epoch : 5 here batch size = 25
# 1896.9594646794726
# Training error after  epoch : 6 here every batch size = 25
# 59.02717121310253
# Validation error after  epoch : 6 here batch size = 25
# 1896.9594573768836
# Training error after  epoch : 7 here every batch size = 25
# 59.02717001000401
# Validation error after  epoch : 7 here batch size = 25
# 1896.9594484697905
# Training error after  epoch : 8 here every batch size = 25
# 59.02716865995176
# Validation error after  epoch : 8 here batch size = 25
# 1896.9594372423908
# Training error after  epoch : 9 here every batch size = 25
# 59.02716710421256
# Validation error after  epoch : 9 here batch size = 25
# 1896.959422592421
# Training error after  epoch : 10 here every batch size = 25
# 59.02716526304508
# Validation error after  epoch : 10 here batch size = 25
# 1896.9594027356604
# Training error after  epoch : 11 here every batch size = 25
# 59.02716302151119
# Validation error after  epoch : 11 here batch size = 25
# 1896.9593746515836
# Training error after  epoch : 12 here every batch size = 25
# 59.027160204789446
# Validation error after  epoch : 12 here batch size = 25
# 1896.9593330225994
# Training error after  epoch : 13 here every batch size = 25
# 59.02715653387085
# Validation error after  epoch : 13 here batch size = 25
# 1896.959268170987
# Training error after  epoch : 14 here every batch size = 25
# 59.027151544189906
# Validation error after  epoch : 14 here batch size = 25
# 1896.9591619942216
# Training error after  epoch : 15 here every batch size = 25
# 59.0271444334342
# Validation error after  epoch : 15 here batch size = 25
# 1896.9589798766428
# Training error after  epoch : 16 here every batch size = 25
# 59.02713377269745
# Validation error after  epoch : 16 here batch size = 25
# 1896.9586544631338
# Training error after  epoch : 17 here every batch size = 25
# 59.027116951767916
# Validation error after  epoch : 17 here batch size = 25
# 1896.9580529022169
# Training error after  epoch : 18 here every batch size = 25
# 59.02708910433608
# Validation error after  epoch : 18 here batch size = 25
# 1896.9569104178154
# Training error after  epoch : 19 here every batch size = 25
# 59.0270410146025
# Validation error after  epoch : 19 here batch size = 25
# 1896.9546952789713
# Training error after  epoch : 20 here every batch size = 25
# 59.026955041433666
# Validation error after  epoch : 20 here batch size = 25
# 1896.9503346185186
# Training error after  epoch : 21 here every batch size = 25
# 59.02679726002388
# Validation error after  epoch : 21 here batch size = 25
# 1896.9416619069584
# Training error after  epoch : 22 here every batch size = 25
# 59.02650270456502
# Validation error after  epoch : 22 here batch size = 25
# 1896.9243266230105
# Training error after  epoch : 23 here every batch size = 25
# 59.02594914674161
# Validation error after  epoch : 23 here batch size = 25
# 1896.8897482898237
# Training error after  epoch : 24 here every batch size = 25
# 59.02491507579767
# Validation error after  epoch : 24 here batch size = 25
# 1896.821713775881
# Training error after  epoch : 25 here every batch size = 25
# 59.02302229755988
# Validation error after  epoch : 25 here batch size = 25
# 1896.6923235943564
# Training error after  epoch : 26 here every batch size = 25
# 59.0196621554791
# Validation error after  epoch : 26 here batch size = 25
# 1896.462096160363
# Training error after  epoch : 27 here every batch size = 25
# 59.013836080431716
# Validation error after  epoch : 27 here batch size = 25
# 1896.0931592052834
# Training error after  epoch : 28 here every batch size = 25
# 59.00369535679304
# Validation error after  epoch : 28 here batch size = 25
# 1895.563172951709
# Training error after  epoch : 29 here every batch size = 25
# 58.98576007195632
# Validation error after  epoch : 29 here batch size = 25
# 1894.819131381149
# Training error after  epoch : 30 here every batch size = 25
# 58.954546172498006
# Validation error after  epoch : 30 here batch size = 25
# 1893.6579186411027
# Training error after  epoch : 31 here every batch size = 25
# 58.903544355910206
# Validation error after  epoch : 31 here batch size = 25
# 1891.682270970009
# Training error after  epoch : 32 here every batch size = 25
# 58.828068863227834
# Validation error after  epoch : 32 here batch size = 25
# 1888.6015357727574
# Training error after  epoch : 33 here every batch size = 25
# 58.727266853095884
# Validation error after  epoch : 33 here batch size = 25
# 1884.5635238934055
# Training error after  epoch : 34 here every batch size = 25
# 58.597864507284406
# Validation error after  epoch : 34 here batch size = 25
# 1879.5545526104256
# Training error after  epoch : 35 here every batch size = 25
# 58.428680290233224
# Validation error after  epoch : 35 here batch size = 25
# 1873.2948420519294
# Training error after  epoch : 36 here every batch size = 25
# 58.210468852255566
# Validation error after  epoch : 36 here batch size = 25
# 1865.7570051093778
# Training error after  epoch : 37 here every batch size = 25
# 57.91710072182153
# Validation error after  epoch : 37 here batch size = 25
# 1855.515656790221
# Training error after  epoch : 38 here every batch size = 25
# 57.51967953281137
# Validation error after  epoch : 38 here batch size = 25
# 1840.396004265469
# Training error after  epoch : 39 here every batch size = 25
# 57.027710213967865
# Validation error after  epoch : 39 here batch size = 25
# 1821.9458732701873
# Training error after  epoch : 40 here every batch size = 25
# 56.451544357642184
# Validation error after  epoch : 40 here batch size = 25
# 1801.8255239521097
# Training error after  epoch : 41 here every batch size = 25
# 55.79782087218606
# Validation error after  epoch : 41 here batch size = 25
# 1781.5645513994277
# Training error after  epoch : 42 here every batch size = 25
# 55.12896386020395
# Validation error after  epoch : 42 here batch size = 25
# 1759.9149961693934
# Training error after  epoch : 43 here every batch size = 25
# 54.47863062605363
# Validation error after  epoch : 43 here batch size = 25
# 1736.234641601162
# Training error after  epoch : 44 here every batch size = 25
# 53.83594565974108
# Validation error after  epoch : 44 here batch size = 25
# 1711.9682054525688
# Training error after  epoch : 45 here every batch size = 25
# 53.19117497756152
# Validation error after  epoch : 45 here batch size = 25
# 1687.9048259585181
# Training error after  epoch : 46 here every batch size = 25
# 52.53886045348741
# Validation error after  epoch : 46 here batch size = 25
# 1663.518057791074
# Training error after  epoch : 47 here every batch size = 25
# 51.8495263513776
# Validation error after  epoch : 47 here batch size = 25
# 1638.7624470866876
# Training error after  epoch : 48 here every batch size = 25
# 51.11556339997818
# Validation error after  epoch : 48 here batch size = 25
# 1613.954749639325
# Training error after  epoch : 49 here every batch size = 25
# 50.33817867872601
# Validation error after  epoch : 49 here batch size = 25
# 1589.6878606943974
# Training error after  epoch : 50 here every batch size = 25
# 49.5246272721224
# Validation error after  epoch : 50 here batch size = 25
# 1566.2465125561648
# Training error after  epoch : 51 here every batch size = 25
# 48.70078400539821
# Validation error after  epoch : 51 here batch size = 25
# 1543.6073551081208
# Training error after  epoch : 52 here every batch size = 25
# 47.86910398175627
# Validation error after  epoch : 52 here batch size = 25
# 1520.9559428780171
# Training error after  epoch : 53 here every batch size = 25
# 47.021935071993056
# Validation error after  epoch : 53 here batch size = 25
# 1497.6808715942936
# Training error after  epoch : 54 here every batch size = 25
# 46.15746822259691
# Validation error after  epoch : 54 here batch size = 25
# 1473.4339702368336
# Training error after  epoch : 55 here every batch size = 25
# 45.27955683285244
# Validation error after  epoch : 55 here batch size = 25
# 1448.3881419298557
# Training error after  epoch : 56 here every batch size = 25
# 44.39927200120725
# Validation error after  epoch : 56 here batch size = 25
# 1422.8238923850424
# Training error after  epoch : 57 here every batch size = 25
# 43.51663180260586
# Validation error after  epoch : 57 here batch size = 25
# 1397.046847605461
# Training error after  epoch : 58 here every batch size = 25
# 42.628710011963214
# Validation error after  epoch : 58 here batch size = 25
# 1371.3992577690628
# Training error after  epoch : 59 here every batch size = 25
# 41.741848473358715
# Validation error after  epoch : 59 here batch size = 25
# 1345.8701177946023
# Training error after  epoch : 60 here every batch size = 25
# 40.87239496216926
# Validation error after  epoch : 60 here batch size = 25
# 1320.59670974855
# Training error after  epoch : 61 here every batch size = 25
# 40.04264262395064
# Validation error after  epoch : 61 here batch size = 25
# 1295.8275450245942
# Training error after  epoch : 62 here every batch size = 25
# 39.26057969374653
# Validation error after  epoch : 62 here batch size = 25
# 1271.389870254455
# Training error after  epoch : 63 here every batch size = 25
# 38.51861702393177
# Validation error after  epoch : 63 here batch size = 25
# 1246.912431171675
# Training error after  epoch : 64 here every batch size = 25
# 37.80870665483518
# Validation error after  epoch : 64 here batch size = 25
# 1222.1628918798729
# Training error after  epoch : 65 here every batch size = 25
# 37.125952360576534
# Validation error after  epoch : 65 here batch size = 25
# 1197.2630054140493
# Training error after  epoch : 66 here every batch size = 25
# 36.46445986456146
# Validation error after  epoch : 66 here batch size = 25
# 1172.5147306776364
# Training error after  epoch : 67 here every batch size = 25
# 35.820258639720016
# Validation error after  epoch : 67 here batch size = 25
# 1148.3695973779895
# Training error after  epoch : 68 here every batch size = 25
# 35.19489799440029
# Validation error after  epoch : 68 here batch size = 25
# 1125.3091665740433
# Training error after  epoch : 69 here every batch size = 25
# 34.594251084668045
# Validation error after  epoch : 69 here batch size = 25
# 1103.7891952218856
# Training error after  epoch : 70 here every batch size = 25
# 34.02384713147621
# Validation error after  epoch : 70 here batch size = 25
# 1084.1384145971113
# Training error after  epoch : 71 here every batch size = 25
# 33.48525233917031
# Validation error after  epoch : 71 here batch size = 25
# 1066.4027439550127
# Training error after  epoch : 72 here every batch size = 25
# 32.97696302486932
# Validation error after  epoch : 72 here batch size = 25
# 1050.3040704078358
# Training error after  epoch : 73 here every batch size = 25
# 32.49458617159781
# Validation error after  epoch : 73 here batch size = 25
# 1035.373077461637
# Training error after  epoch : 74 here every batch size = 25
# 32.03630086284275
# Validation error after  epoch : 74 here batch size = 25
# 1021.1566470243398
# Training error after  epoch : 75 here every batch size = 25
# 31.60323349968613
# Validation error after  epoch : 75 here batch size = 25
# 1007.3551783387011
# Training error after  epoch : 76 here every batch size = 25
# 31.194042580588672
# Validation error after  epoch : 76 here batch size = 25
# 993.8437308010975
# Training error after  epoch : 77 here every batch size = 25
# 30.804028738737404
# Validation error after  epoch : 77 here batch size = 25
# 980.6661310431675
# Training error after  epoch : 78 here every batch size = 25
# 30.428656712434996
# Validation error after  epoch : 78 here batch size = 25
# 968.008486529755
# Training error after  epoch : 79 here every batch size = 25
# 30.0685622366637
# Validation error after  epoch : 79 here batch size = 25
# 956.0495987968185
# Training error after  epoch : 80 here every batch size = 25
# 29.726282368661806
# Validation error after  epoch : 80 here batch size = 25
# 944.8168234119754
# Training error after  epoch : 81 here every batch size = 25
# 29.400098952184177
# Validation error after  epoch : 81 here batch size = 25
# 934.264942334061
# Training error after  epoch : 82 here every batch size = 25
# 29.084867722748783
# Validation error after  epoch : 82 here batch size = 25
# 924.3923370402516
# Training error after  epoch : 83 here every batch size = 25
# 28.775580283551967
# Validation error after  epoch : 83 here batch size = 25
# 915.2964170889828
# Training error after  epoch : 84 here every batch size = 25
# 28.47165002637394
# Validation error after  epoch : 84 here batch size = 25
# 907.0209383793324
# Training error after  epoch : 85 here every batch size = 25
# 28.17521197568243
# Validation error after  epoch : 85 here batch size = 25
# 899.3291314770302
# Training error after  epoch : 86 here every batch size = 25
# 27.885060591928756
# Validation error after  epoch : 86 here batch size = 25
# 891.9445020356175
# Training error after  epoch : 87 here every batch size = 25
# 27.598427600456066
# Validation error after  epoch : 87 here batch size = 25
# 884.7231406228125
# Training error after  epoch : 88 here every batch size = 25
# 27.31479781988596
# Validation error after  epoch : 88 here batch size = 25
# 877.5660032907977
# Training error after  epoch : 89 here every batch size = 25
# 27.036169377815334
# Validation error after  epoch : 89 here batch size = 25
# 870.4431827382913
# Training error after  epoch : 90 here every batch size = 25
# 26.764521586326477
# Validation error after  epoch : 90 here batch size = 25
# 863.3541311471772
# Training error after  epoch : 91 here every batch size = 25
# 26.500773869174438
# Validation error after  epoch : 91 here batch size = 25
# 856.286483709564
# Training error after  epoch : 92 here every batch size = 25
# 26.246474069856117
# Validation error after  epoch : 92 here batch size = 25
# 849.2809611948765
# Training error after  epoch : 93 here every batch size = 25
# 26.00399152058977
# Validation error after  epoch : 93 here batch size = 25
# 842.3968096675294
# Training error after  epoch : 94 here every batch size = 25
# 25.77376478304207
# Validation error after  epoch : 94 here batch size = 25
# 835.5728565396897
# Training error after  epoch : 95 here every batch size = 25
# 25.5543203637499
# Validation error after  epoch : 95 here batch size = 25
# 828.6968537088421
# Training error after  epoch : 96 here every batch size = 25
# 25.345779635663895
# Validation error after  epoch : 96 here batch size = 25
# 821.7510024203209
# Training error after  epoch : 97 here every batch size = 25
# 25.149890880335576
# Validation error after  epoch : 97 here batch size = 25
# 814.8047057157679
# Training error after  epoch : 98 here every batch size = 25
# 24.966629426276107
# Validation error after  epoch : 98 here batch size = 25
# 807.9860714679824
# Training error after  epoch : 99 here every batch size = 25
# 24.79378538151234
# Validation error after  epoch : 99 here batch size = 25
# 801.5119055059488
# Training error after  epoch : 100 here every batch size = 25
# 24.629577446646444
# Validation error after  epoch : 100 here batch size = 25
# 795.6106396598732
# Training Error for 100th epoch for Trail Number : 4
# Training error after  epoch : 1 here every batch size = 25
# 66.25498743148019
# Validation error after  epoch : 1 here batch size = 25
# 1894.1729402686383
# Training error after  epoch : 2 here every batch size = 25
# 59.339172011782225
# Validation error after  epoch : 2 here batch size = 25
# 1894.172934454922
# Training error after  epoch : 3 here every batch size = 25
# 59.339171284612135
# Validation error after  epoch : 3 here batch size = 25
# 1894.172928317072
# Training error after  epoch : 4 here every batch size = 25
# 59.339170534034736
# Validation error after  epoch : 4 here batch size = 25
# 1894.1729214576903
# Training error after  epoch : 5 here every batch size = 25
# 59.3391697327871
# Validation error after  epoch : 5 here batch size = 25
# 1894.1729134175653
# Training error after  epoch : 6 here every batch size = 25
# 59.339168850553335
# Validation error after  epoch : 6 here batch size = 25
# 1894.1729036277316
# Training error after  epoch : 7 here every batch size = 25
# 59.339167851969904
# Validation error after  epoch : 7 here batch size = 25
# 1894.1728913478196
# Training error after  epoch : 8 here every batch size = 25
# 59.339166694140005
# Validation error after  epoch : 8 here batch size = 25
# 1894.1728755830022
# Training error after  epoch : 9 here every batch size = 25
# 59.33916532339638
# Validation error after  epoch : 9 here batch size = 25
# 1894.1728549678007
# Training error after  epoch : 10 here every batch size = 25
# 59.33916367094096
# Validation error after  epoch : 10 here batch size = 25
# 1894.172827600529
# Training error after  epoch : 11 here every batch size = 25
# 59.33916164684008
# Validation error after  epoch : 11 here batch size = 25
# 1894.172790804707
# Training error after  epoch : 12 here every batch size = 25
# 59.339159131601775
# Validation error after  epoch : 12 here batch size = 25
# 1894.1727407817827
# ...
# 48.99532872348981
# Validation error after  epoch : 50 here batch size = 25
# 1547.9347334610782
# Training error after  epoch : 51 here every batch size = 25
# 48.151315009077074
# Validation error after  epoch : 51 here batch size = 25
# 1519.9563510078865
# Training error after  epoch : 52 here every batch size = 25
# 47.31927822675219
# Validation error after  epoch : 52 here batch size = 25
# 1492.9173326725418
# Training error after  epoch : 53 here every batch size = 25
# 46.50071137105264
# Validation error after  epoch : 53 here batch size = 25
# 1466.5744140489874
# Training error after  epoch : 54 here every batch size = 25
# 45.695460387623385
# Validation error after  epoch : 54 here batch size = 25
# 1440.347870535961
# Training error after  epoch : 55 here every batch size = 25
# 44.90242059032569
# Validation error after  epoch : 55 here batch size = 25
# 1413.6280643968457
# Training error after  epoch : 56 here every batch size = 25
# 44.11139990503068
# Validation error after  epoch : 56 here batch size = 25
# 1386.902429917295
# Training error after  epoch : 57 here every batch size = 25
# 43.313255007694515
# Validation error after  epoch : 57 here batch size = 25
# 1360.8367809243796
# Training error after  epoch : 58 here every batch size = 25
# 42.50326063253709
# Validation error after  epoch : 58 here batch size = 25
# 1335.906232520696
# Training error after  epoch : 59 here every batch size = 25
# 41.68138111784982
# Validation error after  epoch : 59 here batch size = 25
# 1312.8384387496446
# Training error after  epoch : 60 here every batch size = 25
# 40.85280814883284
# Validation error after  epoch : 60 here batch size = 25
# 1291.6616891968033
# Training error after  epoch : 61 here every batch size = 25
# 40.032689837803424
# Validation error after  epoch : 61 here batch size = 25
# 1271.8598502033024
# Training error after  epoch : 62 here every batch size = 25
# 39.241821563542665
# Validation error after  epoch : 62 here batch size = 25
# 1252.4915982281304
# Training error after  epoch : 63 here every batch size = 25
# 38.48423627577393
# Validation error after  epoch : 63 here batch size = 25
# 1232.749759910806
# Training error after  epoch : 64 here every batch size = 25
# 37.749143490416515
# Validation error after  epoch : 64 here batch size = 25
# 1212.5688064012186
# Training error after  epoch : 65 here every batch size = 25
# 37.027622103949355
# Validation error after  epoch : 65 here batch size = 25
# 1192.159576265734
# Training error after  epoch : 66 here every batch size = 25
# 36.31729566000922
# Validation error after  epoch : 66 here batch size = 25
# 1171.7025437641985
# Training error after  epoch : 67 here every batch size = 25
# 35.61788299630923
# Validation error after  epoch : 67 here batch size = 25
# 1151.2749018065297
# Training error after  epoch : 68 here every batch size = 25
# 34.92461046110026
# Validation error after  epoch : 68 here batch size = 25
# 1130.6518952977572
# Training error after  epoch : 69 here every batch size = 25
# 34.232307381030516
# Validation error after  epoch : 69 here batch size = 25
# 1109.5475261794008
# Training error after  epoch : 70 here every batch size = 25
# 33.53912352200495
# Validation error after  epoch : 70 here batch size = 25
# 1087.9431361238048
# Training error after  epoch : 71 here every batch size = 25
# 32.85279682784623
# Validation error after  epoch : 71 here batch size = 25
# 1066.3627561171452
# Training error after  epoch : 72 here every batch size = 25
# 32.19243167048665
# Validation error after  epoch : 72 here batch size = 25
# 1045.4219391073011
# Training error after  epoch : 73 here every batch size = 25
# 31.566011652450843
# Validation error after  epoch : 73 here batch size = 25
# 1025.522059305942
# Training error after  epoch : 74 here every batch size = 25
# 30.972807185640033
# Validation error after  epoch : 74 here batch size = 25
# 1007.0812822565222
# Training error after  epoch : 75 here every batch size = 25
# 30.41046968168118
# Validation error after  epoch : 75 here batch size = 25
# 990.3992443387725
# Training error after  epoch : 76 here every batch size = 25
# 29.875611157140085
# Validation error after  epoch : 76 here batch size = 25
# 975.3475957082987
# Training error after  epoch : 77 here every batch size = 25
# 29.368741741134958
# Validation error after  epoch : 77 here batch size = 25
# 961.596225066321
# Training error after  epoch : 78 here every batch size = 25
# 28.892525851883583
# Validation error after  epoch : 78 here batch size = 25
# 948.8112630021008
# Training error after  epoch : 79 here every batch size = 25
# 28.444345496327706
# Validation error after  epoch : 79 here batch size = 25
# 936.629003606161
# Training error after  epoch : 80 here every batch size = 25
# 28.020019347331015
# Validation error after  epoch : 80 here batch size = 25
# 924.9898376999976
# Training error after  epoch : 81 here every batch size = 25
# 27.61810308725404
# Validation error after  epoch : 81 here batch size = 25
# 914.071327827218
# Training error after  epoch : 82 here every batch size = 25
# 27.23803513585946
# Validation error after  epoch : 82 here batch size = 25
# 903.9136116328301
# Training error after  epoch : 83 here every batch size = 25
# 26.87880983459166
# Validation error after  epoch : 83 here batch size = 25
# 894.4211545203161
# Training error after  epoch : 84 here every batch size = 25
# 26.54046758740774
# Validation error after  epoch : 84 here batch size = 25
# 885.5965294887121
# Training error after  epoch : 85 here every batch size = 25
# 26.224192634506917
# Validation error after  epoch : 85 here batch size = 25
# 877.4120148306338
# Training error after  epoch : 86 here every batch size = 25
# 25.931336069770826
# Validation error after  epoch : 86 here batch size = 25
# 869.8417980402975
# Training error after  epoch : 87 here every batch size = 25
# 25.661218785080827
# Validation error after  epoch : 87 here batch size = 25
# 862.9312909066806
# Training error after  epoch : 88 here every batch size = 25
# 25.408230215443886
# Validation error after  epoch : 88 here batch size = 25
# 856.69110606111
# Training error after  epoch : 89 here every batch size = 25
# 25.16563524351638
# Validation error after  epoch : 89 here batch size = 25
# 851.0864765936722
# Training error after  epoch : 90 here every batch size = 25
# 24.929230440376095
# Validation error after  epoch : 90 here batch size = 25
# 846.0585701002346
# Training error after  epoch : 91 here every batch size = 25
# 24.697748091073322
# Validation error after  epoch : 91 here batch size = 25
# 841.4899145497733
# Training error after  epoch : 92 here every batch size = 25
# 24.47200507125984
# Validation error after  epoch : 92 here batch size = 25
# 837.2107999956191
# Training error after  epoch : 93 here every batch size = 25
# 24.25377514347993
# Validation error after  epoch : 93 here batch size = 25
# 833.087530862377
# Training error after  epoch : 94 here every batch size = 25
# 24.04428108540534
# Validation error after  epoch : 94 here batch size = 25
# 829.0566268090727
# Training error after  epoch : 95 here every batch size = 25
# 23.843549584004915
# Validation error after  epoch : 95 here batch size = 25
# 825.0998132874547
# Training error after  epoch : 96 here every batch size = 25
# 23.651368115380503
# Validation error after  epoch : 96 here batch size = 25
# 821.2250090476064
# Training error after  epoch : 97 here every batch size = 25
# 23.467888233947104
# Validation error after  epoch : 97 here batch size = 25
# 817.452354650292
# Training error after  epoch : 98 here every batch size = 25
# 23.291980649417024
# Validation error after  epoch : 98 here batch size = 25
# 813.7803208511177
# Training error after  epoch : 99 here every batch size = 25
# 23.1221923695964
# Validation error after  epoch : 99 here batch size = 25
# 810.1749411843464
# Training error after  epoch : 100 here every batch size = 25
# 22.95815062428564
# Validation error after  epoch : 100 here batch size = 25
# 806.5969048288438
#
#
# Final Training Errors after 5 trails and 100 Epocs :
# [62.3457837674732, 59.06188348545383, 59.061882925765204, 59.06188234866398, 59.06188173503599, 59.06188106370736, 59.06188031006082, 59.06187944430622, 59.061878429197264, 59.06187721689739, 59.061875744539655, 59.06187392778859, 59.06187165129382, 59.06186875425932, 59.06186500820806, 59.06186008207321, 59.06185348636407, 59.06184448216237, 59.06183192993866, 59.06181403346267, 59.06178789727654, 59.06174874623028, 59.061688519950145, 59.06159328726797, 59.06143838693928, 59.0611790982972, 59.06073235054919, 59.05994013818117, 59.058495068428265, 59.05578732386602, 59.05059165059715, 59.04046775199933, 59.02114242346771, 58.98680133969262, 58.929177182677066, 58.836500567080094, 58.69322998510932, 58.47521954731209, 58.152851057133184, 57.6992765775301, 57.08452258075084, 56.327115950062, 55.43282921101497, 54.43684266673143, 53.35312575927818, 52.226163784805784, 51.084733371420214, 49.934553875869824, 48.78939709969528, 47.65232926331409, 46.533473591729184, 45.4606381371853, 44.45444644614465, 43.506607453597006, 42.59895901357355, 41.72021293820769, 40.870576388165304, 40.059268090984645, 39.290719721054096, 38.55677319307354, 37.843032195752606, 37.141961508204055, 36.45444075967677, 35.782880733564255, 35.128239546808565, 34.4923645552189, 33.878090065413254, 33.28511117504497, 32.713418092808816, 32.17077687864714, 31.666854806945008, 31.20825578662071, 30.796899768668027, 30.427177467751115, 30.090546260853145, 29.780458152193, 29.49409977278614, 29.228991911169825, 28.981703577684414, 28.751930396868936, 28.540142432300687, 28.34614169637409, 28.16863062244446, 28.00381666209166, 27.848051057580307, 27.70275050889682, 27.57277841418583, 27.459897294403447, 27.361978911098987, 27.27695045538038, 27.205405643962294, 27.15193799114239, 27.120396219967958, 27.10853725950485, 27.109420509534793, 27.116819509013578, 27.129020774180315, 27.14555144418386, 27.163705830415804, 27.1807934468786, 63.39119142216914, 58.95747615909826, 58.957474378990334, 58.957472528697934, 58.957470555303175, 58.957468398085, 58.957465984413446, 58.95746322425022, 58.95746000249228, 58.957456167981256, 58.95745151733491, 58.95744577063772, 58.95743853416958, 58.9574292422126, 58.95741706459769, 58.95740075737092, 58.95737841772596, 58.957347075694344, 58.95730200404442, 58.95723553629157, 58.95713501801625, 58.95697922134496, 58.95673203071862, 58.9563313193778, 58.955669538226196, 58.95456071359841, 58.952687320714595, 58.94952350447964, 58.9442471970472, 58.93569474145995, 58.922447852244865, 58.90299642719237, 58.875630603814706, 58.83805078934997, 58.78681055496026, 58.71632405462707, 58.618982984955366, 58.48191261336032, 58.28307108039368, 58.01164840614641, 57.67879559163741, 57.29706155088787, 56.81830741489744, 56.18979208638056, 55.42704861821652, 54.54319194885584, 53.56945418509602, 52.559566430476906, 51.533365542380025, 50.50945689559893, 49.50172640010065, 48.504763048783914, 47.48882955264947, 46.431195418700035, 45.34820159737107, 44.26500957768039, 43.19402382588912, 42.14388137866686, 41.12558217872428, 40.16125044367022, 39.25922675584082, 38.4102073054679, 37.601806516713204, 36.829549155976636, 36.09363289445415, 35.3921296063684, 34.716386610014865, 34.059542356981716, 33.42130739152712, 32.80694791636485, 32.22679325545284, 31.693168555303245, 31.20676736230492, 30.755164621851574, 30.327899982642972, 29.91653861482085, 29.519227012027695, 29.14722071304041, 28.80397557445063, 28.475920406208054, 28.15326773792613, 27.840056637222414, 27.545078418669206, 27.270138956093437, 27.018133467534664, 26.790124412868423, 26.585328306597006, 26.40444969643509, 26.246868374411193, 26.113034098369518, 26.006913719011795, 25.931388177783553, 25.884582999194002, 25.861214578555376, 25.85561508008083, 25.86507418311885, 25.890366854213237, 25.935669394188004, 26.002666403062694, 26.085590433882377, 70.0779121046555, 59.027175397882885, 59.02717437185014, 59.02717335639018, 59.027172315491846, 59.02717121310253, 59.02717001000401, 59. ...
#
#
# Final Validation Errors after 5 trails and 100 Epocs :
# [1935.7913784426432, 1935.7913711171036, 1935.79136345994, 1935.7913549942505, 1935.791345176319, 1935.7913333448337, 1935.7913186575202, 1935.7913000075173, 1935.7912759092349, 1935.7912443392886, 1935.7912025111214, 1935.7911465530283, 1935.791071042812, 1935.7909683300365, 1935.7908275394022, 1935.790633091092, 1935.7903624796072, 1935.7899828977545, 1935.78944603223, 1935.7886799074536, 1935.7875758617747, 1935.785967297331, 1935.783594151877, 1935.7800418325103, 1935.7746329192494, 1935.7662280999723, 1935.752844610804, 1935.730887412019, 1935.693504512984, 1935.6268179544948, 1935.500680007724, 1935.2453295622845, 1934.699771253349, 1933.569826929322, 1931.656116481691, 1928.8862983685258, 1924.1033565836678, 1916.1269196521275, 1903.5257627463943, 1885.668718344165, 1862.103664340826, 1833.5285027809468, 1801.7562606177016, 1768.3687957704037, 1733.4645323192658, 1697.5768630167186, 1662.6580446409564, 1628.595236427009, 1595.1803875009132, 1563.2130537406163, 1533.6306350239793, 1505.6802263247596, 1478.1276430233715, 1449.466814507337, 1420.2846386134906, 1391.380107607562, 1363.035390592675, 1335.5073359434602, 1308.3341714392532, 1281.3840717965095, 1254.7386969995605, 1228.4156277950328, 1202.6232408096234, 1177.6651319730704, 1153.6916782966555, 1130.6615440479193, 1108.4579424239591, 1086.9586683784055, 1065.9880163879416, 1045.3452144953994, 1024.889629366542, 1004.6567882741444, 984.8232376584829, 965.5663743155089, 947.0637242466315, 929.6601821828461, 914.0573713681056, 900.6637920603439, 889.3084059469993, 879.5482688771884, 870.7707978024846, 862.4706646226339, 854.4447769004371, 846.7416375168739, 839.4888607403193, 832.7705211189337, 826.4759941274317, 820.3101548985492, 814.0707374707999, 807.78823908498, 801.7172761046344, 796.2046471083913, 791.4836545690621, 787.6122625181351, 784.5495884482455, 782.2330380276966, 780.59811175305, 779.5556951400474, 779.0218467975174, 778.9038922503171, 1892.0706374710157, 1892.0706164900125, 1892.0705949655437, 1892.0705717377755, 1892.0705454569315, 1892.070514445325, 1892.0704765068494, 1892.0704286497357, 1892.0703666712586, 1892.07028452114, 1892.0701733088008, 1892.0700197335866, 1892.0698035745636, 1892.0694936342143, 1892.0690411244927, 1892.0683687931676, 1892.067352914562, 1892.0657932701433, 1892.0633628509981, 1892.05952330928, 1892.0533828144273, 1892.043458292839, 1892.027283290834, 1892.0007800348822, 1891.95730875258, 1891.886367217388, 1891.7720941820298, 1891.5918825724061, 1891.31470118721, 1890.8965827096756, 1890.2731450119359, 1889.365057232058, 1888.107453335289, 1886.462060117843, 1884.371024972827, 1881.5925626496823, 1877.5401371736439, 1871.8314204097146, 1864.3277459172718, 1854.0380646787605, 1840.0181001909195, 1822.2204379645607, 1800.833091893613, 1776.2115046633817, 1750.1089938452549, 1723.0090852038747, 1695.2314614648967, 1665.5032324724416, 1632.253361676179, 1597.938678947085, 1564.7275610731103, 1532.575748242176, 1500.09580357287, 1466.9524241194235, 1432.9628920994687, 1398.5088168695984, 1365.6058535544853, 1334.916785517537, 1306.027741905672, 1278.6886757610573, 1252.8381873208423, 1227.6436194467478, 1202.307440510111, 1177.3702742514984, 1153.668245492573, 1131.4723921094032, 1110.2651970006336, 1089.3981596428648, 1068.8047019650758, 1049.0093176449204, 1030.3747881391291, 1012.9123031529696, 996.3547114776736, 980.5957026583914, 965.908796985478, 952.5697362722392, 940.678176489464, 930.0056685242524, 920.1777521949066, 911.0765842754556, 903.0345288477515, 896.4300237949808, 891.2837004785715, 887.3170777359892, 884.1751751933882, 881.7358811701695, 880.1306028106945, 879.5521532449703, 880.022331961611, 881.3787356776261, 883.4090407562599, 885.9452421526863, 888.8711394904703, 892.0745927678308, 895.4550916388285, 899.0382273665391, 902.9992625208895, 907.4927723609784, 912.4695195563007, 917.7766383246208, 1896.9594859942372, 1896.9594812657788, 1896.9594763038242, 1896.9594708688574, 1896.9594646794726, 1896.9594573 ...
#
#
# Plots are started to Generate In Figures Folder :
# Plots are Generated Successfully In Figures folder

# %% [markdown]
# ## Observation -
#
# a) On increasing the number of epochs, the model strength of fitting the complex data increases.
#
# b) On increasing the number of Epochs, varaince increases, indicating that there is a slight over fitting.
#
# c) On increasing the number of epochs, training error and validation error decreases as the model become more capable of fitting complex data.
